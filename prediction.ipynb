# %% [markdown]
# ##### import theano
#
# from stocker import Stocker

# %%
from stocker import Stocker
import flask
import pygments
#from flask_restless import *
from flask_restful import Resource, Api

# %%
fbstock = Stocker('FB')
# Out:
# Error Retrieving Data.
# (Status 429) (Quandl Error QELx01) You have exceeded the anonymous user limit of 50 calls per day. To make more calls today, please register for a free Quandl account and then include your API key with your requests.

# %%
fbstock.plot_stock()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-60610734f722> in <module>()
# ----> 1 fbstock.plot_stock()
#
# ~\Downloads\IST 652\Project\stocker.py in plot_stock(self, start_date, end_date, stats, plot_type)
#     225
#     226         if start_date is None:
# --> 227             start_date = self.min_date
#     228         if end_date is None:
#     229             end_date = self.max_date
#
# AttributeError: 'Stocker' object has no attribute 'min_date'

# %%
 fbstock.evaluate_prediction()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9b1822b3bb79> in <module>()
# ----> 1 fbstock.evaluate_prediction()
#
# ~\Downloads\IST 652\Project\stocker.py in evaluate_prediction(self, start_date, end_date, nshares)
#     489         # Default end date is end date of data
#     490         if start_date is None:
# --> 491             start_date = self.max_date - pd.DateOffset(years=1)
#     492         if end_date is None:
#     493             end_date = self.max_date
#
# AttributeError: 'Stocker' object has no attribute 'max_date'

# %%
fbbar= fbstock.predict_future(days=100)

# %%
# predict days into the future
model, model_data = fbstock.create_prophet_model(days=90)
# Out:
# c:\users\sapan badjatiya\appdata\local\programs\python\python36-32\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2018-06-25 = $179.90

# %%
fbstock.evaluate_prediction(start_date = '2018-04-21', end_date = '2018-04-25', nshares=100)

# %%
fbstock.predict_future(days=30)
